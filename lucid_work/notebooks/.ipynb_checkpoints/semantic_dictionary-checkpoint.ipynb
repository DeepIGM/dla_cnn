# %%
import numpy as np
import tensorflow as tf


from sklearn.preprocessing import normalize
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

from PIL import Image
import math
import requests
from io import BytesIO


import lucid.modelzoo.vision_models as models
import lucid.optvis.render as render
from lucid.misc.io import show, load
from lucid.misc.io.showing import _image_url
import lucid.scratch.web.svelte as lucid_svelte

# %%
from lucid.modelzoo.vision_base import Model

class DLA(Model):
    model_path = 'https://storage.googleapis.com/dla_protobuff/full_model_8_13.pb'
    image_shape = [1, 400]
    image_value_range = [0, 1]
    input_name = 'x'

# %%
# %%html_define_svelte SemanticDict
#
# <div class="figure">
#     <div class="input_image">
#         <div class="image" style="background-image: url({{image_url}}); z-index: -10;"></div>
#         <svg class="pointer_container" viewBox="0 50 {{N[0]}} {{N[1]}}">
#
#             {{#each xs as x}}
#             {{#each ys as y}}
#               <rect x={{x}} y={{y}} width=1 height=267
#                 class={{(x == pos[0] && y == pos[1])? "selected" : "unselected"}}
#                 on:mouseover="set({pos: [x,y]})"></rect>
#             {{/each}}
#             {{/each}}
#         </svg>
#     </div>
#     <div class="dict" >
#         {{#each present_acts as act, act_ind}}
#         <div class="entry">
#             <div class="sprite" style="background-image: url({{spritemap_url}}); width: {{210}}px; height: {{157}}px; background-position: -{{210*(act.n%sprite_n_wrap)}}px -{{157*Math.floor(act.n/sprite_n_wrap)}}px; --info: {{act.n}};"></div>
#             <div class="value" style="height: {{sprite_size*act.v/200.0}}px;"></div>
#         </div>
#         {{/each}}
#     </div>
# </div>
#
#
# <style>
#     .figure {
#         padding: 10px;
#         width: 2048px;
#     }
#     .input_image {
#         display: inline-block;
#         width: 400px;
#         height: 267px;
#     }
#     .input_image .image, .input_image .pointer_container {
#         position: absolute;
#         width: 400px;
#         height: 267px;
#         border-radius: 8px;
#     }
#     .pointer_container rect {
#       opacity: 0;
#     }
#     .pointer_container .selected {
#       opacity: 1;
#       fill: none;
#       stroke: hsl(24, 100%, 50%);
#       stroke-width: .1px;
#     }
#
#     .dict {
#         height: 128px;
#         display: inline-block;
#         vertical-align: bottom;
#         padding-bottom: 64px;
#         margin-left: 64px;
#     }
#     .entry {
#         margin-top: 9px;
#         margin-right: 32px;
#         display: inline-block;
#     }
#     .value {
#         display: inline-block;
#         width: 32px;
#         border-radius: 8px;
#         background: #777;
#     }
#     .sprite {
#         display: inline-block;
#         border-radius: 8px;
#     }
#     .dict-text {
#         display: none;
#         font-size: 24px;
#         color: #AAA;
#         margin-bottom: 20px;
#     }
# </style>
#
# <script>
#
#   function range(n){
#     return Array(n).fill().map((_, i) => i);
#   }
#
#   export default {
#     data () {
#       return {
#         spritemap_url: "",
#         sprite_size: 64,
#         sprite_n_wrap: 1e8,
#         image_url: "",
#         activations: [[[{n: 0, v: 1}]]],
#         pos: [0,0]
#       };
#     },
#     computed: {
#       present_acts: (activations, pos) => activations[pos[0]][0],
#       N: activations => [activations.length, activations[0].length],
#       xs: (N) => range(N[0]),
#       ys: (N) => range(N[1])
#     },
#     helpers: {range}
#   };
# </script>
# Out:
# Trying to build svelte component from html...
# svelte compile --format iife /tmp/svelte_2zwq9ooq/SemanticDict_71a7fa75_4c8d_4173_859c_5f57c141df16.html > /tmp/svelte_2zwq9ooq/SemanticDict_71a7fa75_4c8d_4173_859c_5f57c141df16.js
# b'svelte version 1.64.1\ncompiling ../../../../../../tmp/svelte_2zwq9ooq/SemanticDict_71a7fa75_4c8d_4173_859c_5f57c141df16.html...\n'

# %%
LAYERS = { 'conv1': 'Conv2D',
           'conv1_relu':'Relu',
           'pool1': 'MaxPool',
           'conv2': 'Conv2D_1',
           'conv2_relu': 'Relu_1',
           'pool2': 'MaxPool_1',
           'conv3': 'Conv2D_2',
           'conv3_relu': 'Relu_2',
           'pool3': 'MaxPool_2',
           'fc1': 'MatMul',
           'fc1_relu': 'Relu_3'}


layer_spritemap_sizes = {
    'conv1': 10,
    'conv1_relu': 10, 
    'pool1': 10,
    'conv2': 12,
    'conv2_relu': 12,
    'pool2': 12,
    'conv3': 12,
    'conv3_relu': 12,
    'pool3': 12,
    'fc1': 25,
    'fc1_relu': 25}


def dla_spritemap(layer):
    assert layer in layer_spritemap_sizes
    size = layer_spritemap_sizes[layer]
    url = "https://storage.googleapis.com/dla_spritemaps/1d_spritemaps/%s.png" % layer
    return size, url

# %%
model = DLA()
model.load_graphdef()


def dla_semantic_dict(layer, test_input, img_file):
    model_layer = LAYERS[layer]
    
    input_1d = test_input # Actual 1-Dimensional test input
    img = load(img_file)
    
    # Compute the activations
    with tf.Graph().as_default(), tf.Session():
        t_input = tf.placeholder(tf.float32, shape=[1, 400, 1, 1])
        T = render.import_model(model, t_input, t_input)
        acts = T(model_layer).eval({t_input: input_1d})[0]
        
    
    # Find best position for our initial view
    max_mag = acts.max(-1)
    max_x = np.argmax(max_mag.max(-1))
    #print(max_x)
    
    # Find appropriate spritemap
    spritemap_n, spritemap_url = dla_spritemap(layer)
    
    
    # Actually construct the semantic dictionary interface
    # using our *custom component*
    lucid_svelte.SemanticDict({
        "spritemap_url": spritemap_url,
        "sprite_size": 210,
        "sprite_n_wrap": spritemap_n,
        "image_url": _image_url(img),
        "activations": [[[{"n": float(n), "v": float(act_vec[n])} for n in np.argsort(-act_vec)[:1]] for act_vec in act_slice] for act_slice in acts],
        "pos" : [float(max_x), 0]
    })
    return acts

# %%
def get_pos_activations(pos, activations):
    x = pos[0]
    y = pos[1]
    present_acts = activations[x][y]
    return present_acts

def get_sprite_dims(acts, spritemap_wrap, sprite_size):
    sprites = []
    for s in acts:
        n = s['n']
        v = s['v']
        x = int(n % spritemap_wrap) * 210
        y = math.floor(n/spritemap_wrap) * 157
        dim = [x, y]
        val = [dim, v]
        sprites.append(val)
    return sprites

def load_sprites(s_dims, sprite_size, img):
    sprites = []
    for i in range(4):
        value = s_dims[i][1]
        left = s_dims[i][0][0]
        upper = s_dims[i][0][1]
        right = left + 210
        lower = upper + 157
        crop_rectangle = (left, upper, right, lower)
        cropped_im = img.crop(crop_rectangle)
        val = cropped_im, value
        sprites.append(val)
    return sprites
        
def display_sprites(sprites):
    for i in range(len(sprites)):
        print(sprites[i][1])
        display(sprites[i][0])   
        
def best_four(layer, x, activations):
    acts = [[[{"n": float(n), "v": float(act_vec[n])} for n in np.argsort(-act_vec)[:4]] for act_vec in act_slice] for act_slice in activations]
    spritemap_n, spritemap_url = dla_spritemap(layer)
    sprite_size = 210
    spritemap_wrap = spritemap_n 
    
    response = requests.get(spritemap_url)
    img = Image.open(BytesIO(response.content))
    
    p_acts = get_pos_activations([x,0], acts)
    s_dims = get_sprite_dims(p_acts, spritemap_wrap, sprite_size)
    sprites = load_sprites(s_dims, sprite_size, img)
    display_sprites(sprites)

# %%
def resize_input(image_file):
    img = Image.open(image_file)
    img = img.resize((400,267), Image.ANTIALIAS)
    img.save(image_file)

# %%
def run(data, start, layer, norm):
    flux = np.load(data)
    if norm:
        flux *= 1/flux.max()
    flux_test = flux[start:start+400]
    flux_test = flux_test.reshape(1, 400, 1, 1)
    flux_graph = flux_test.reshape(400)
    fig = plt.figure(frameon=False);
    ax = plt.Axes(fig, [0, 0, 1, 1]);
    ax.set_axis_off();
    fig.add_axes(ax);
    ax.plot(flux_graph, 'black');
    ax.set(xlim=(0, 400));
    file_save = 'flux_' + str(start) + '.png'
    fig.savefig(file_save);
    plt.close(fig)
    resize_input(file_save)
    acts = dla_semantic_dict(layer, flux_test, file_save)
    return acts

# %%
# DLA is present in this first image with atrt point 0
acts = run('../data/flux.npy', 0, 'conv1', True)
# Out:
#   <div id='SemanticDict_71a7fa75_4c8d_4173_859c_5f57c141df16_10d1720c_a277_4ca1_a0e1_1036d0286c9b'></div>
#   <script>
#   /* tmp/svelte_2zwq9ooq/SemanticDict_71a7fa75_4c8d_4173_859c_5f57c141df16.html generated by Svelte v1.64.1 */
# var SemanticDict_71a7fa75_4c8d_4173_859c_5f57c141df16 = (function() { "use strict";
#
# 	function range(n){
#   return Array(n).fill().map((_, i) => i);
# }
#
# function present_acts(activations, pos) {
# 		return activations[pos[0]][0];
# 	}
#
# 	function N(activations) {
# 		return [activations.length, activations[0].length];
# 	}
#
# 	function xs(N) {
# 		return range(N[0]);
# 	}
#
# 	function ys(N) {
# 		return range(N[1]);
# 	}
#
# 	function data() {
#   return {
#     spritemap_url: "",
#     sprite_size: 64,
#     sprite_n_wrap: 1e8,
#     image_url: "",
#     activations: [[[{n: 0, v: 1}]]],
#     pos: [0,0]
#   };
# };
#
# 	function add_css() {
# 		var style = createElement("style");
# 		style.id = 'svelte-qn7vas-style';
# 		style.textContent = ".svelte-qn7vas.figure,.svelte-qn7vas .figure{padding:10px;width:2048px}.svelte-qn7vas.input_image,.svelte-qn7vas .input_image{display:inline-block;width:400px;height:267px}.svelte-qn7vas.input_image .image,.svelte-qn7vas .input_image .image,.svelte-qn7vas.input_image .pointer_container,.svelte-qn7vas .input_image .pointer_container{position:absolute;width:400px;height:267px;border-radius:8px}.svelte-qn7vas.pointer_container rect,.svelte-qn7vas .pointer_container rect{opacity:0}.svelte-qn7vas.pointer_container .selected,.svelte-qn7vas .pointer_container .selected{opacity:1;fill:none;stroke:hsl(24, 100%, 50%);stroke-width:.1px}.svelte-qn7vas.dict,.svelte-qn7vas .dict{height:128px;display:inline-block;vertical-align:bottom;padding-bottom:64px;margin-left:64px}.svelte-qn7vas.entry,.svelte-qn7vas .entry{margin-top:9px;margin-right:32px;display:inline-block}.svelte-qn7vas.value,.svelte-qn7vas .value{display:inline-block;width:32px;border-radius:8px;background:#777}.svelte-qn7vas.sprite,.svelte-qn7vas .sprite{display:inline-block;border-radius:8px}.svelte-qn7vas.dict-text,.svelte-qn7vas .dict-text{display:none;font-size:24px;color:#AAA;margin-bottom:20px}";
# 		appendNode(style, document.head);
# 	}
#
# 	function create_main_fragment(component, state) {
# 		var div, div_1, div_2, text, svg, svg_viewBox_value, text_2, div_3;
#
# 		var each_value = state.xs;
#
# 		var each_blocks = [];
#
# 		for (var i = 0; i < each_value.length; i += 1) {
# 			each_blocks[i] = create_each_block(component, assign(assign({}, state), {
# 				each_value: each_value,
# 				x: each_value[i],
# 				x_index: i
# 			}));
# 		}
#
# 		var each_value_2 = state.present_acts;
#
# 		var each_1_blocks = [];
#
# 		for (var i = 0; i < each_value_2.length; i += 1) {
# 			each_1_blocks[i] = create_each_block_2(component, assign(assign({}, state), {
# 				each_value_2: each_value_2,
# 				act: each_value_2[i],
# 				act_ind: i
# 			}));
# 		}
#
# 		return {
# 			c: function create() {
# 				div = createElement("div");
# 				div_1 = createElement("div");
# 				div_2 = createElement("div");
# 				text = createText("\n        ");
# 				svg = createSvgElement("svg");
#
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].c();
# 				}
#
# 				text_2 = createText("\n    ");
# 				div_3 = createElement("div");
#
# 				for (var i = 0; i < each_1_blocks.length; i += 1) {
# 					each_1_blocks[i].c();
# 				}
# 				this.h();
# 			},
#
# 			h: function hydrate() {
# 				div_2.className = "image";
# 				setStyle(div_2, "background-image", "url(" + state.image_url + ")");
# 				setStyle(div_2, "z-index", "-10");
# 				setAttribute(svg, "class", "pointer_container");
# 				setAttribute(svg, "viewBox", svg_viewBox_value = "0 50 " + state.N[0] + " " + state.N[1]);
# 				div_1.className = "input_image";
# 				div_3.className = "dict";
# 				div.className = "figure svelte-qn7vas";
# 			},
#
# 			m: function mount(target, anchor) {
# 				insertNode(div, target, anchor);
# 				appendNode(div_1, div);
# 				appendNode(div_2, div_1);
# 				appendNode(text, div_1);
# 				appendNode(svg, div_1);
#
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].m(svg, null);
# 				}
#
# 				appendNode(text_2, div);
# 				appendNode(div_3, div);
#
# 				for (var i = 0; i < each_1_blocks.length; i += 1) {
# 					each_1_blocks[i].m(div_3, null);
# 				}
# 			},
#
# 			p: function update(changed, state) {
# 				if (changed.image_url) {
# 					setStyle(div_2, "background-image", "url(" + state.image_url + ")");
# 				}
#
# 				var each_value = state.xs;
#
# 				if (changed.ys || changed.xs || changed.pos) {
# 					for (var i = 0; i < each_value.length; i += 1) {
# 						var each_context = assign(assign({}, state), {
# 							each_value: each_value,
# 							x: each_value[i],
# 							x_index: i
# 						});
#
# 						if (each_blocks[i]) {
# 							each_blocks[i].p(changed, each_context);
# 						} else {
# 							each_blocks[i] = create_each_block(component, each_context);
# 							each_blocks[i].c();
# 							each_blocks[i].m(svg, null);
# 						}
# 					}
#
# 					for (; i < each_blocks.length; i += 1) {
# 						each_blocks[i].u();
# 						each_blocks[i].d();
# 					}
# 					each_blocks.length = each_value.length;
# 				}
#
# 				if ((changed.N) && svg_viewBox_value !== (svg_viewBox_value = "0 50 " + state.N[0] + " " + state.N[1])) {
# 					setAttribute(svg, "viewBox", svg_viewBox_value);
# 				}
#
# 				var each_value_2 = state.present_acts;
#
# 				if (changed.spritemap_url || changed.present_acts || changed.sprite_n_wrap || changed.Math || changed.sprite_size) {
# 					for (var i = 0; i < each_value_2.length; i += 1) {
# 						var each_1_context = assign(assign({}, state), {
# 							each_value_2: each_value_2,
# 							act: each_value_2[i],
# 							act_ind: i
# 						});
#
# 						if (each_1_blocks[i]) {
# 							each_1_blocks[i].p(changed, each_1_context);
# 						} else {
# 							each_1_blocks[i] = create_each_block_2(component, each_1_context);
# 							each_1_blocks[i].c();
# 							each_1_blocks[i].m(div_3, null);
# 						}
# 					}
#
# 					for (; i < each_1_blocks.length; i += 1) {
# 						each_1_blocks[i].u();
# 						each_1_blocks[i].d();
# 					}
# 					each_1_blocks.length = each_value_2.length;
# 				}
# 			},
#
# 			u: function unmount() {
# 				detachNode(div);
#
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].u();
# 				}
#
# 				for (var i = 0; i < each_1_blocks.length; i += 1) {
# 					each_1_blocks[i].u();
# 				}
# 			},
#
# 			d: function destroy() {
# 				destroyEach(each_blocks);
#
# 				destroyEach(each_1_blocks);
# 			}
# 		};
# 	}
#
# 	// (7:12) {{#each xs as x}}
# 	function create_each_block(component, state) {
# 		var x = state.x, each_value = state.each_value, x_index = state.x_index;
# 		var each_anchor;
#
# 		var each_value_1 = state.ys;
#
# 		var each_blocks = [];
#
# 		for (var i = 0; i < each_value_1.length; i += 1) {
# 			each_blocks[i] = create_each_block_1(component, assign(assign({}, state), {
# 				each_value_1: each_value_1,
# 				y: each_value_1[i],
# 				y_index: i
# 			}));
# 		}
#
# 		return {
# 			c: function create() {
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].c();
# 				}
#
# 				each_anchor = createComment();
# 			},
#
# 			m: function mount(target, anchor) {
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].m(target, anchor);
# 				}
#
# 				insertNode(each_anchor, target, anchor);
# 			},
#
# 			p: function update(changed, state) {
# 				x = state.x;
# 				each_value = state.each_value;
# 				x_index = state.x_index;
# 				var each_value_1 = state.ys;
#
# 				if (changed.xs || changed.ys || changed.pos) {
# 					for (var i = 0; i < each_value_1.length; i += 1) {
# 						var each_context = assign(assign({}, state), {
# 							each_value_1: each_value_1,
# 							y: each_value_1[i],
# 							y_index: i
# 						});
#
# 						if (each_blocks[i]) {
# 							each_blocks[i].p(changed, each_context);
# 						} else {
# 							each_blocks[i] = create_each_block_1(component, each_context);
# 							each_blocks[i].c();
# 							each_blocks[i].m(each_anchor.parentNode, each_anchor);
# 						}
# 					}
#
# 					for (; i < each_blocks.length; i += 1) {
# 						each_blocks[i].u();
# 						each_blocks[i].d();
# 					}
# 					each_blocks.length = each_value_1.length;
# 				}
# 			},
#
# 			u: function unmount() {
# 				for (var i = 0; i < each_blocks.l
