# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
import math
import requests
from io import BytesIO


import lucid.modelzoo.vision_models as models
import lucid.optvis.render as render
from lucid.misc.io import show, load
from lucid.misc.io.showing import _image_url
import lucid.scratch.web.svelte as lucid_svelte

# %%
# %%html_define_svelte SemanticDict
#
# <div class="figure">
#     <div class="input_image">
#         <div class="image" style="background-image: url({{image_url}}); z-index: -10;"></div>
#         <svg class="pointer_container" viewBox="0 0 {{N[0]}} {{N[1]}}">
#
#             {{#each xs as x}}
#             {{#each ys as y}}
#               <rect x={{x}} y={{y}} width=1 height=1
#                 class={{(x == pos[0] && y == pos[1])? "selected" : "unselected"}}
#                 on:mouseover="set({pos: [x,y]})"></rect>
#             {{/each}}
#             {{/each}}
#         </svg>
#     </div>
#     <div class="dict" >
#         {{#each present_acts as act, act_ind}}
#         <div class="entry">
#             <div class="sprite" style="background-image: url({{spritemap_url}}); width: {{sprite_size}}px; height: {{sprite_size}}px; background-position: -{{sprite_size*(act.n%sprite_n_wrap)}}px -{{sprite_size*Math.floor(act.n/sprite_n_wrap)}}px; --info: {{act.n}};"></div>
#             <div class="value" style="height: {{sprite_size*act.v/1000.0}}px;"></div>
#         </div>
#         {{/each}}
#     </div>
# </div>
#
#
# <style>
#     .figure {
#         padding: 10px;
#         width: 1024px;
#     }
#     .input_image {
#         display: inline-block;
#         width: 400px;
#         height: 267px;
#     }
#     .input_image .image, .input_image .pointer_constainer {
#         position: absolute;
#         width: 400px;
#         height: 267px;
#         border-radius: 8px;
#     }
#     .pointer_container rect {
#       opacity: 0;
#     }
#     .pointer_container .selected {
#       opacity: 1;
#       fill: none;
#       stroke: hsl(24, 100%, 50%);
#       stroke-width: 0.1px;
#     }
#
#     .dict {
#         height: 128px;
#         display: inline-block;
#         vertical-align: bottom;
#         padding-bottom: 64px;
#         margin-left: 64px;
#     }
#     .entry {
#         margin-top: 9px;
#         margin-right: 32px;
#         display: inline-block;
#     }
#     .value {
#         display: inline-block;
#         width: 32px;
#         border-radius: 8px;
#         background: #777;
#     }
#     .sprite {
#         display: inline-block;
#         border-radius: 8px;
#     }
#     .dict-text {
#         display: none;
#         font-size: 24px;
#         color: #AAA;
#         margin-bottom: 20px;
#     }
# </style>
#
# <script>
#
#   function range(n){
#     return Array(n).fill().map((_, i) => i);
#   }
#
#   export default {
#     data () {
#       return {
#         spritemap_url: "",
#         sprite_size: 64,
#         sprite_n_wrap: 1e8,
#         image_url: "",
#         activations: [[[{n: 0, v: 1}]]],
#         pos: [0,0]
#       };
#     },
#     computed: {
#       present_acts: (activations, pos) => activations[pos[1]][pos[0]],
#       N: activations => [activations.length, activations[0].length],
#       xs: (N) => range(N[0]),
#       ys: (N) => range(N[1])
#     },
#     helpers: {range}
#   };
# </script>
# Out:
# Trying to build svelte component from html...
# svelte compile --format iife /tmp/svelte_r9ng50v6/SemanticDict_ff49d617_ca0f_42c3_a2be_21099b3f9373.html > /tmp/svelte_r9ng50v6/SemanticDict_ff49d617_ca0f_42c3_a2be_21099b3f9373.js
# b'svelte version 1.64.1\ncompiling ../../../../../tmp/svelte_r9ng50v6/SemanticDict_ff49d617_ca0f_42c3_a2be_21099b3f9373.html...\n'

# %%
from lucid.modelzoo.vision_base import Model

class DLA(Model):
    model_path = 'https://storage.googleapis.com/dla_protobuff/full_model_8_13.pb'
    image_shape = [1, 400]
    image_value_range = [0, 1]
    input_name = 'x'

# %%
LAYERS = { 'conv1': 'Conv2D',
           'conv1_relu':'Relu',
           'pool1': 'MaxPool',
           'conv2': 'Conv2D_1',
           'conv2_relu': 'Relu_1',
           'pool2': 'MaxPool_1',
           'conv3': 'Conv2D_2',
           'conv3_relu': 'Relu_2',
           'pool3': 'MaxPool_2',
           'fc1': 'MatMul',
           'fc1_relu': 'Relu_3'}


layer_spritemap_sizes = {
    'conv1': 10,
    'conv1_relu': 10, 
    'pool1': 10,
    'conv2': 12,
    'conv2_relu': 12,
    'pool2': 12,
    'conv3': 12,
    'conv3_relu': 12,
    'pool3': 12,
    'fc1': 25,
    'fc1_relu': 25}


def dla_spritemap(layer):
    assert layer in layer_spritemap_sizes
    size = layer_spritemap_sizes[layer]
    url = "https://storage.googleapis.com/dla_spritemaps/spritemap_%s.jpeg" % layer
    return size, url

# %%
model = DLA()
model.load_graphdef()


def dla_semantic_dict(layer, test_input, img_file):
    # This is where we need to get the input of 400
    
    model_layer = LAYERS[layer]
    
    
    input_1d = test_input # Actual 1-Dimensional test input
    img = load(img_file)
    
    # Compute the activations
    with tf.Graph().as_default(), tf.Session():
        t_input = tf.placeholder(tf.float32, shape=[1, 400, 1, 1])
        T = render.import_model(model, t_input, t_input)
        acts = T(model_layer).eval({t_input: input_1d})[0]
    
    
    # Find appropriate spritemap
    spritemap_n, spritemap_url = dla_spritemap(layer)
    
    
    # Actually construct the semantic dictionary interface
    # using our *custom component*
    lucid_svelte.SemanticDict({
        "spritemap_url": spritemap_url,
        "sprite_size": 116,
        "sprite_n_wrap": spritemap_n,
        "image_url": _image_url(img),
        "activations": [[[{"n": float(n), "v": float(act_vec[n])} for n in np.argsort(-act_vec)[:4]] for act_vec in act_slice] for act_slice in acts],
        #"pos" : [float(max_y), float(max_x)]
        "pos": [0,0]
    })
    
        
    return acts

# %%
test_input = np.random.random([1, 400, 1, 1])

# %%
# values = []
# for i in range(400):
#     values.append(test_input[0][i][0][0])
    
# fig = plt.figure(frameon=False)

# ax = plt.Axes(fig, [0,0,1,1])
# ax.set_axis_off()
# fig.add_axes(ax)


# ax.plot(values, 'black');
# ax.set(xlim=(0, 400), ylim=(0, 1));
# fig.savefig('test.png')

# %%
# image = Image.open('test.png')
# image = image.convert('RGB')
# image.save('test.jpg', 'JPEG')

# %%
acts = dla_semantic_dict('conv1', test_input, 'https://storage.googleapis.com/dla_input/test_resized.jpg')
# Out:
#   <div id='SemanticDict_ff49d617_ca0f_42c3_a2be_21099b3f9373_0494ed37_4c90_41e8_9e8c_651daa4cbb78'></div>
#   <script>
#   /* tmp/svelte_r9ng50v6/SemanticDict_ff49d617_ca0f_42c3_a2be_21099b3f9373.html generated by Svelte v1.64.1 */
# var SemanticDict_ff49d617_ca0f_42c3_a2be_21099b3f9373 = (function() { "use strict";
#
# 	function range(n){
#   return Array(n).fill().map((_, i) => i);
# }
#
# function present_acts(activations, pos) {
# 		return activations[pos[1]][pos[0]];
# 	}
#
# 	function N(activations) {
# 		return [activations.length, activations[0].length];
# 	}
#
# 	function xs(N) {
# 		return range(N[0]);
# 	}
#
# 	function ys(N) {
# 		return range(N[1]);
# 	}
#
# 	function data() {
#   return {
#     spritemap_url: "",
#     sprite_size: 64,
#     sprite_n_wrap: 1e8,
#     image_url: "",
#     activations: [[[{n: 0, v: 1}]]],
#     pos: [0,0]
#   };
# };
#
# 	function add_css() {
# 		var style = createElement("style");
# 		style.id = 'svelte-34otau-style';
# 		style.textContent = ".svelte-34otau.figure,.svelte-34otau .figure{padding:10px;width:1024px}.svelte-34otau.input_image,.svelte-34otau .input_image{display:inline-block;width:400px;height:267px}.svelte-34otau.input_image .image,.svelte-34otau .input_image .image,.svelte-34otau.input_image .pointer_constainer,.svelte-34otau .input_image .pointer_constainer{position:absolute;width:400px;height:267px;border-radius:8px}.svelte-34otau.pointer_container rect,.svelte-34otau .pointer_container rect{opacity:0}.svelte-34otau.pointer_container .selected,.svelte-34otau .pointer_container .selected{opacity:1;fill:none;stroke:hsl(24, 100%, 50%);stroke-width:0.1px}.svelte-34otau.dict,.svelte-34otau .dict{height:128px;display:inline-block;vertical-align:bottom;padding-bottom:64px;margin-left:64px}.svelte-34otau.entry,.svelte-34otau .entry{margin-top:9px;margin-right:32px;display:inline-block}.svelte-34otau.value,.svelte-34otau .value{display:inline-block;width:32px;border-radius:8px;background:#777}.svelte-34otau.sprite,.svelte-34otau .sprite{display:inline-block;border-radius:8px}.svelte-34otau.dict-text,.svelte-34otau .dict-text{display:none;font-size:24px;color:#AAA;margin-bottom:20px}";
# 		appendNode(style, document.head);
# 	}
#
# 	function create_main_fragment(component, state) {
# 		var div, div_1, div_2, text, svg, svg_viewBox_value, text_2, div_3;
#
# 		var each_value = state.xs;
#
# 		var each_blocks = [];
#
# 		for (var i = 0; i < each_value.length; i += 1) {
# 			each_blocks[i] = create_each_block(component, assign(assign({}, state), {
# 				each_value: each_value,
# 				x: each_value[i],
# 				x_index: i
# 			}));
# 		}
#
# 		var each_value_2 = state.present_acts;
#
# 		var each_1_blocks = [];
#
# 		for (var i = 0; i < each_value_2.length; i += 1) {
# 			each_1_blocks[i] = create_each_block_2(component, assign(assign({}, state), {
# 				each_value_2: each_value_2,
# 				act: each_value_2[i],
# 				act_ind: i
# 			}));
# 		}
#
# 		return {
# 			c: function create() {
# 				div = createElement("div");
# 				div_1 = createElement("div");
# 				div_2 = createElement("div");
# 				text = createText("\n        ");
# 				svg = createSvgElement("svg");
#
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].c();
# 				}
#
# 				text_2 = createText("\n    ");
# 				div_3 = createElement("div");
#
# 				for (var i = 0; i < each_1_blocks.length; i += 1) {
# 					each_1_blocks[i].c();
# 				}
# 				this.h();
# 			},
#
# 			h: function hydrate() {
# 				div_2.className = "image";
# 				setStyle(div_2, "background-image", "url(" + state.image_url + ")");
# 				setStyle(div_2, "z-index", "-10");
# 				setAttribute(svg, "class", "pointer_container");
# 				setAttribute(svg, "viewBox", svg_viewBox_value = "0 0 " + state.N[0] + " " + state.N[1]);
# 				div_1.className = "input_image";
# 				div_3.className = "dict";
# 				div.className = "figure svelte-34otau";
# 			},
#
# 			m: function mount(target, anchor) {
# 				insertNode(div, target, anchor);
# 				appendNode(div_1, div);
# 				appendNode(div_2, div_1);
# 				appendNode(text, div_1);
# 				appendNode(svg, div_1);
#
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].m(svg, null);
# 				}
#
# 				appendNode(text_2, div);
# 				appendNode(div_3, div);
#
# 				for (var i = 0; i < each_1_blocks.length; i += 1) {
# 					each_1_blocks[i].m(div_3, null);
# 				}
# 			},
#
# 			p: function update(changed, state) {
# 				if (changed.image_url) {
# 					setStyle(div_2, "background-image", "url(" + state.image_url + ")");
# 				}
#
# 				var each_value = state.xs;
#
# 				if (changed.ys || changed.xs || changed.pos) {
# 					for (var i = 0; i < each_value.length; i += 1) {
# 						var each_context = assign(assign({}, state), {
# 							each_value: each_value,
# 							x: each_value[i],
# 							x_index: i
# 						});
#
# 						if (each_blocks[i]) {
# 							each_blocks[i].p(changed, each_context);
# 						} else {
# 							each_blocks[i] = create_each_block(component, each_context);
# 							each_blocks[i].c();
# 							each_blocks[i].m(svg, null);
# 						}
# 					}
#
# 					for (; i < each_blocks.length; i += 1) {
# 						each_blocks[i].u();
# 						each_blocks[i].d();
# 					}
# 					each_blocks.length = each_value.length;
# 				}
#
# 				if ((changed.N) && svg_viewBox_value !== (svg_viewBox_value = "0 0 " + state.N[0] + " " + state.N[1])) {
# 					setAttribute(svg, "viewBox", svg_viewBox_value);
# 				}
#
# 				var each_value_2 = state.present_acts;
#
# 				if (changed.spritemap_url || changed.sprite_size || changed.present_acts || changed.sprite_n_wrap || changed.Math) {
# 					for (var i = 0; i < each_value_2.length; i += 1) {
# 						var each_1_context = assign(assign({}, state), {
# 							each_value_2: each_value_2,
# 							act: each_value_2[i],
# 							act_ind: i
# 						});
#
# 						if (each_1_blocks[i]) {
# 							each_1_blocks[i].p(changed, each_1_context);
# 						} else {
# 							each_1_blocks[i] = create_each_block_2(component, each_1_context);
# 							each_1_blocks[i].c();
# 							each_1_blocks[i].m(div_3, null);
# 						}
# 					}
#
# 					for (; i < each_1_blocks.length; i += 1) {
# 						each_1_blocks[i].u();
# 						each_1_blocks[i].d();
# 					}
# 					each_1_blocks.length = each_value_2.length;
# 				}
# 			},
#
# 			u: function unmount() {
# 				detachNode(div);
#
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].u();
# 				}
#
# 				for (var i = 0; i < each_1_blocks.length; i += 1) {
# 					each_1_blocks[i].u();
# 				}
# 			},
#
# 			d: function destroy() {
# 				destroyEach(each_blocks);
#
# 				destroyEach(each_1_blocks);
# 			}
# 		};
# 	}
#
# 	// (7:12) {{#each xs as x}}
# 	function create_each_block(component, state) {
# 		var x = state.x, each_value = state.each_value, x_index = state.x_index;
# 		var each_anchor;
#
# 		var each_value_1 = state.ys;
#
# 		var each_blocks = [];
#
# 		for (var i = 0; i < each_value_1.length; i += 1) {
# 			each_blocks[i] = create_each_block_1(component, assign(assign({}, state), {
# 				each_value_1: each_value_1,
# 				y: each_value_1[i],
# 				y_index: i
# 			}));
# 		}
#
# 		return {
# 			c: function create() {
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].c();
# 				}
#
# 				each_anchor = createComment();
# 			},
#
# 			m: function mount(target, anchor) {
# 				for (var i = 0; i < each_blocks.length; i += 1) {
# 					each_blocks[i].m(target, anchor);
# 				}
#
# 				insertNode(each_anchor, target, anchor);
# 			},
#
# 			p: function update(changed, state) {
# 				x = state.x;
# 				each_value = state.each_value;
# 				x_index = state.x_index;
# 				var each_value_1 = state.ys;
#
# 				if (changed.xs || changed.ys || changed.pos) {
# 					for (var i = 0; i < each_value_1.length; i += 1) {
# 						var each_context = assign(assign({}, state), {
# 							each_value_1: each_value_1,
# 							y: each_value_1[i],
# 							y_index: i
# 						});
#
# 						if (each_blocks[i]) {
# 							each_blocks[i].p(changed, each_context);
# 						} else {
# 							each_blocks[i] = create_each_block_1(component, each_context);
# 							each_blocks[i].c();
# 							each_blocks[i].m(each_anchor.parentNode, each_anchor);
# 						}
# 					}
#
# 					for (; i < each_blocks.length; i += 1) {
# 						each_blocks[i].u();
# 						each_blocks[i].d();
# 					}
# 					each_blocks.length = each_value_1.length;
# 				}
# 			},
#
# 			u: function unmount() {
# 				for (var i = 0; i < each_bl

# %%
activations = [[[{"n": float(n), "v": float(act_vec[n])} for n in np.argsort(-act_vec)[:4]] for act_vec in act_slice] for act_slice in acts]
spritemap_n, spritemap_url = dla_spritemap('conv1')
sprite_size = 116
spritemap_wrap = spritemap_n

# %%
def get_pos_activations(pos):
    x = pos[0]
    y = pos[1]
    present_acts = activations[x][y]
    return present_acts

def get_sprite_dims(acts):
    sprites = []
    for s in acts:
        n = s['n']
        v = s['v']
        x = int(n % spritemap_wrap) * sprite_size
        y = math.floor(n/spritemap_wrap) * sprite_size
        dim = [x, y]
        val = [dim, v]
        sprites.append(val)
    return sprites

# %%
def load_sprites(s_dims):
    sprites = []
    for i in range(4):
        value = s_dims[i][1]
        left = s_dims[i][0][0]
        upper = s_dims[i][0][1]
        right = left + sprite_size
        lower = upper + sprite_size
        crop_rectangle = (left, upper, right, lower)
        cropped_im = img.crop(crop_rectangle)
        val = cropped_im, value
        sprites.append(val)
    return sprites
        
def display_sprites(sprites):
    for i in range(len(sprites)):
        print(sprites[i][1])
        display(sprites[i][0])

# %%
response = requests.get(spritemap_url)
img = Image.open(BytesIO(response.content))


p_acts = get_pos_activations([0,0])
s_dims = get_sprite_dims(p_acts)
sprites = load_sprites(s_dims)
display_sprites(sprites)
